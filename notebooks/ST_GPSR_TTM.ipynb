# %%
# %matplotlib inline
from bokeh.io import output_notebook
from bokeh.plotting import *
from matmodlab2 import *
from numpy import *
output_notebook()
import numpy as np
import pandas as pd
# Out:
# Setting up the Matmodlab notebook environment
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e52e4fb9-51bf-43df-981a-34d34037b60a">Loading BokehJS ...</span>
#     </div>

# %%
tests_to_run = [
                0, 
                # 1,
                # 2, 
                # 3, 
                # 4
                ]

# %%
if 0 in tests_to_run:
    #B = array([ [ 1, 0, 0], [0, 1, 0 ], [ 0, 0, 1 ] ])
    def B(eqps):
        B_in = array([ [ 1, 0, 0], [0, 1, 0 ], [ 0, 0, 1 ] ])
        return B_in

    mps1 = MaterialPointSimulator('uplastic-std')
    p = {'E': 10e6, 'Nu': .333, 'Y0': 1e3, "B": B}
    mps1.material = ST_GPSR_TTM(**p)
    mps1.run_step('ESS', (.001, 0, 0), frames=50)

    i = where((mps1.df['E.XX'] > 0.) & (mps1.df['E.XX'] < .005))
    E = mps1.df['S.XX'].iloc[i] / mps1.df['E.XX'].iloc[i]

    mps1.plot('E.XX', 'S.XX')

# %%
if 0 in tests_to_run:
    def B(X_0):
        B_copy = (array([[0.40193716, 0.4875574 , 0.42782397],
            [0.4875574 , 0.39968126, 0.43621872],
            [0.42782397, 0.43621872, 0.4665371 ]])) * ((X_0)/(X_0 + array([[0.12679382]]))  + array([[-2.04994375]]) + array([[0.12679382]]) + X_0)
        #return np.linalg.inv(B_copy)
        return B_copy
    
    mps1 = MaterialPointSimulator('uplastic-std')
    p = {'E': 10e6, 'Nu': .333, 'Y0': 1, "H": 1, "B": B}
    mps1.material = ST_GPSR_TTM(**p)
    mps1.run_step('ESS', (.001, 0, 0), frames=50)

    i = where((mps1.df['E.XX'] > 0.) & (mps1.df['E.XX'] < .005))
    E = mps1.df['S.XX'].iloc[i] / mps1.df['E.XX'].iloc[i]
    
    mps1.plot('E.XX', 'S.XX')
    print(mps1.df['EQPS'])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 12
#      10 p = {'E': 10e6, 'Nu': .333, 'Y0': 1, "H": 1, "B": B}
#      11 mps1.material = ST_GPSR_TTM(**p)
# ---> 12 mps1.run_step('ESS', (.001, 0, 0), frames=50)
#      14 i = where((mps1.df['E.XX'] > 0.) & (mps1.df['E.XX'] < .005))
#      15 E = mps1.df['S.XX'].iloc[i] / mps1.df['E.XX'].iloc[i]
#
# File d:\work\software\matmodlab2\matmodlab2\core\matmodlab.py:472, in MaterialPointSimulator.run_step(self, descriptors, components, increment, frames, scale, kappa, temperature, time_whole, ufield)
#     470 logger.info("\rRunning step {0}... ".format(istep), extra=continued)
#     471 assert step.begin == previous_step.end
# --> 472 self.run_istep(
#     473     istep,
#     474     step.begin,
#     475     step.end,
#     476     step.frames,
#     477     step.descriptors,
#     478     step.components,
# ...

# %%
if 2 in tests_to_run:
    B = array([ [ 0.7, 0, 0], [0, 1, 0 ], [ 0, 0, 1 ] ])


    mps1 = MaterialPointSimulator('uplastic-std')
    p = {'E': 10e6, 'Nu': .333, 'Y0': 1e3, "B": B}
    mps1.material = ST_GPSR_TTM(**p)
    mps1.run_step('ESS', (.0004, 0, 0), frames=500)


    mps1.plot('E.XX', 'S.XX')

# %%
if 3 in tests_to_run:
    B = .18 * array([[4.84938514, -1.39136693, 3.57891267],
                      [0.92418741, 2.16747212, 3.7473522],
                      [2.52797065, 1.72322281, 2.07687239]])

    mps1 = MaterialPointSimulator('uplastic-std')
    p = {'E': 10e6, 'Nu': .333, 'Y0': 1e3, "B": B}
    mps1.material = ST_GPSR_TTM(**p)
    mps1.run_step('SES', (0., 0.004, 0), frames=500)

    mps1.plot('E.YY', 'S.YY')

# %%
if 4 in tests_to_run:
    B = array( [ [ -0.225, 0.39, 0.23], [-0.093, 0.41, 0.075], [ -0.258, 0.512, 0.139] ])*5.298


    mps1 = MaterialPointSimulator('uplastic-std')
    p = {'E': 10e6, 'Nu': .333, 'Y0': 1e3, "B": B}
    mps1.material = ST_GPSR_TTM(**p)
    mps1.run_step('EES', (0.001, .01*1.1, 0), frames=500)


    mps1.plot('E.XX', 'S.XX')
    mps1.plot('E.YY', 'S.YY')
    mps1.plot('E.ZZ', 'S.ZZ')
    print(dot(linalg.inv(B),[0,1,0]))

# if 4 in tests_to_run:
#     B = array( [ [ -0.225, 0.39, 0.23], [-0.093, 0.41, 0.075], [ -0.258, 0.512, 0.139] ])*5.298


#     mps1 = MaterialPointSimulator('uplastic-std')
#     p = {'E': 10e6, 'Nu': .333, 'Y0': 1e3, "B": B}
#     mps1.material = ST_GPSR_TTM(**p)
#     mps1.run_step('SES', (0, 0.0001, 0), frames=50)


#     mps1.plot('E.YY', 'S.YY')

#     print(dot(linalg.inv(B),[1,1,1]))

# %%
if 0 in tests_to_run:
    B = array([ [ 1, 0, 0], [0, 1, 0 ], [ 0, 0, 1 ] ])

    mps1 = MaterialPointSimulator('uplastic-std')
    p = {'E': 10e6, 'Nu': .333, 'Y0': 1e3, "B": B}
    mps1.material = HardeningPlasticMaterial(**p)
    mps1.run_step('SSSESS', (0,0,0,0.001,0,0), frames=50)

    mps1.plot('E.XY', 'S.XY')
# Out:
# Unused parameters: B
